# %%
import numpy as np
import pandas as pd

# %%
facebook=pd.read_csv('/home/muskan/B part/facebook.csv')

# %%
facebook.head()
# Out:
#    pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 0          139441     2         2         12            4         3     0
# 1          139441     3         2         12            3        10     0
# 2          139441     2         3         12            3         3     0
# 3          139441     2         2         12            2        10     1
# 4          139441     2         2         12            2         3     0
#
#    lifetimeposttotalreach  lifetimeposttotalimpressions  lifetimeengagedusers  \
# 0                    2752                          5091                   178
# 1                   10460                         19057                  1457
# 2                    2413                          4373                   177
# 3                   50128                         87991                  2211
# 4                    7244                         13594                   671
#
# ...

# %%
air_quality=pd.read_csv('air_quality.csv')

# %%
air_quality.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18:00:00     2.6         1360       150      11.9
# 1  10/03/2004  19:00:00     2.0         1292       112       9.4
# 2  10/03/2004  20:00:00     2.2         1402        88       9.0
# 3  10/03/2004  21:00:00     2.2         1376        80       9.2
# 4  10/03/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
fb1=facebook[['pagetotallikes','type','category']]

# %%
fb1.head()
# Out:
#    pagetotallikes  type  category
# 0          139441     2         2
# 1          139441     3         2
# 2          139441     2         3
# 3          139441     2         2
# 4          139441     2         2

# %%
fb2=facebook[['pagetotallikes','posthour','paid']]

# %%
fb2.head()
# Out:
#    pagetotallikes  posthour  paid
# 0          139441         3     0
# 1          139441        10     0
# 2          139441         3     0
# 3          139441        10     1
# 4          139441         3     0

# %%
mer=pd.merge(fb1,fb2,on="pagetotallikes")

# %%
mer.head()
# Out:
#    pagetotallikes  type  category  posthour  paid
# 0          139441     2         2         3     0
# 1          139441     2         2        10     0
# 2          139441     2         2         3     0
# 3          139441     2         2        10     1
# 4          139441     2         2         3     0

# %%
fb_sort=facebook.sort_values(by='like',ascending=False)

# %%
fb_sort
# Out:
#      pagetotallikes  type  category  postmonth  postweekday  posthour  paid  \
# 252          111620     2         3          4            1        14     1
# 222          117764     2         3          5            5        13     0
# 3            139441     2         2         12            2        10     1
# 333           92507     2         3          2            1        13     0
# 101          137020     2         2         10            4         3     0
# 196          123047     2         3          6            1        10     0
# 105          137020     2         1         10            2         4     0
# 139          136013     3         2         10            3         2     1
# 219          117764     2         3          5            7         2     0
# 264          109670     2         2          4            1        13     1
# 67           138185     2         1         11            7         3     1
# ...

# %%
fb_transpose=facebook.T

# %%
fb_transpose.head()
# Out:
#                    0       1       2       3       4       5       6    \
# pagetotallikes  139441  139441  139441  139441  139441  139441  139441
# type                 2       3       2       2       2       3       2
# category             2       2       3       2       2       2       3
# postmonth           12      12      12      12      12      12      12
# postweekday          4       3       3       2       2       1       1
#
#                    7       8       9    ...    362    363    364    365  \
# pagetotallikes  139441  139441  139441  ...  85979  85979  85979  85979
# type                 2       3       2  ...      2      2      2      1
# category             3       2       3  ...      3      3      3      1
# postmonth           12      12      12  ...      1      1      1      1
# postweekday          7       7       6  ...      7      6      6      5
#
#                   366    367    368    369    370    371
# ...

# %%
fb_melt=facebook.melt(var_val)

# %%
fb_melt
# Out:
#                variable   value
# 0        pagetotallikes  139441
# 1        pagetotallikes  139441
# 2        pagetotallikes  139441
# 3        pagetotallikes  139441
# 4        pagetotallikes  139441
# 5        pagetotallikes  139441
# 6        pagetotallikes  139441
# 7        pagetotallikes  139441
# 8        pagetotallikes  139441
# 9        pagetotallikes  139441
# 10       pagetotallikes  139441
# 11       pagetotallikes  139441
# 12       pagetotallikes  139441
# 13       pagetotallikes  139441
# 14       pagetotallikes  138414
# 15       pagetotallikes  138414
# 16       pagetotallikes  138414
# 17       pagetotallikes  138414
# 18       pagetotallikes  138414
# 19       pagetotallikes  138414
# 20       pagetotallikes  138414
# 21       pagetotallikes  138414
# 22       pagetotallikes  138414
# 23       pagetotallikes  138414
# 24       pagetotallikes  138414
# 25       pagetotallikes  138458
# 26       pagetotallikes  138458
# 27       pagetotallikes  138458
# ...

# %%
air_quality
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18:00:00     2.6         1360       150      11.9
# 1     10/03/2004  19:00:00     2.0         1292       112       9.4
# 2     10/03/2004  20:00:00     2.2         1402        88       9.0
# 3     10/03/2004  21:00:00     2.2         1376        80       9.2
# 4     10/03/2004  22:00:00     1.6         1272        51       6.5
# 5     10/03/2004  23:00:00     1.2         1197        38       4.7
# 6     11/03/2004  00:00:00     1.2         1185        31       3.6
# 7     11/03/2004  01:00:00     1.0         1136        31       3.3
# 8     11/03/2004  02:00:00     0.9         1094        24       2.3
# 9     11/03/2004  03:00:00     0.6         1010        19       1.7
# 10    11/03/2004  04:00:00  -200.0         1011        14       1.3
# 11    11/03/2004  05:00:00     0.7         1066         8       1.1
# 12    11/03/2004  06:00:00     0.7         1052        16       1.6
# ...

# %%
air_quality.shape
# Out:
# (9357, 15)

# %%
new_air=air_quality.drop_duplicates(['Time'])

# %%
new_air.shape
# Out:
# (24, 15)

# %%
new_air
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0   10/03/2004  18:00:00     2.6         1360       150      11.9
# 1   10/03/2004  19:00:00     2.0         1292       112       9.4
# 2   10/03/2004  20:00:00     2.2         1402        88       9.0
# 3   10/03/2004  21:00:00     2.2         1376        80       9.2
# 4   10/03/2004  22:00:00     1.6         1272        51       6.5
# 5   10/03/2004  23:00:00     1.2         1197        38       4.7
# 6   11/03/2004  00:00:00     1.2         1185        31       3.6
# 7   11/03/2004  01:00:00     1.0         1136        31       3.3
# 8   11/03/2004  02:00:00     0.9         1094        24       2.3
# 9   11/03/2004  03:00:00     0.6         1010        19       1.7
# 10  11/03/2004  04:00:00  -200.0         1011        14       1.3
# 11  11/03/2004  05:00:00     0.7         1066         8       1.1
# 12  11/03/2004  06:00:00     0.7         1052        16       1.6
# ...

# %%
air_cast=new_air.pivot(index='Time',columns='CO(GT)',values='NO2(GT)')

# %%
air_cast
# Out:
# CO(GT)    -200.0   0.6     0.7     0.9     1.0     1.1     1.2     1.5    \
# Time
# 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN    77.0     NaN
# 01:00:00     NaN     NaN     NaN     NaN    76.0     NaN     NaN     NaN
# 02:00:00     NaN     NaN     NaN    60.0     NaN     NaN     NaN     NaN
# 03:00:00     NaN  -200.0     NaN     NaN     NaN     NaN     NaN     NaN
# 04:00:00    34.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 05:00:00     NaN     NaN    28.0     NaN     NaN     NaN     NaN     NaN
# 06:00:00     NaN     NaN    48.0     NaN     NaN     NaN     NaN     NaN
# 07:00:00     NaN     NaN     NaN     NaN     NaN    82.0     NaN     NaN
# 08:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 09:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN    92.0
# ...
